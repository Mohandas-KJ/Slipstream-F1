# %% [markdown]
# # Tyre and Stint Analysis

# %%
#Imports
import sys
import importlib
sys.path.append("../..")
import Sliplib.slipload as sl
import Sliplib.selection as slipsel
import Sliplib.plotting as slpolt
import Sliplib.GridSum as grid

importlib.reload(slpolt)
importlib.reload(slipsel)
importlib.reload(grid)
# Out:
# <module 'Sliplib.GridSum' from '/mnt/Windows/Projects_S1/ProjectSlipstream/2026_Barcelona_GP/notebooks/../../Sliplib/GridSum.py'>

# %%
# Select GP and Load Session
session = sl.load_gp(2025,"Spanish Grand Prix","Race")
session.load()
# Out:
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.8.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 19 drivers: ['81', '4', '16', '63', '27', '44', '6', '10', '14', '1', '30', '5', '22', '55', '43', '31', '87', '12', '23']

# %%
#Load Lap data and head them
lap_data = session.laps
lap_data.head(5)
# Out:
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 01:00:37.344000    VER            1 0 days 00:01:23.696000
# 1 0 days 01:01:57.427000    VER            1 0 days 00:01:20.083000
# 2 0 days 01:03:17.964000    VER            1 0 days 00:01:20.537000
# 3 0 days 01:04:38.996000    VER            1 0 days 00:01:21.032000
# 4 0 days 01:05:59.960000    VER            1 0 days 00:01:20.964000
#
#    LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# 0        1.0    1.0        NaT       NaT                    NaT
# 1        2.0    1.0        NaT       NaT 0 days 00:00:24.125000
# 2        3.0    1.0        NaT       NaT 0 days 00:00:23.816000
# 3        4.0    1.0        NaT       NaT 0 days 00:00:24.299000
# 4        5.0    1.0        NaT       NaT 0 days 00:00:24.223000
#
#              Sector2Time  ... FreshTyre             Team  \
# 0 0 days 00:00:32.318000  ...     False  Red Bull Racing
# ...

# %%
# Select a Driver
ver = lap_data.pick_drivers("VER")
ver.head(5)
# Out:
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 01:00:37.344000    VER            1 0 days 00:01:23.696000
# 1 0 days 01:01:57.427000    VER            1 0 days 00:01:20.083000
# 2 0 days 01:03:17.964000    VER            1 0 days 00:01:20.537000
# 3 0 days 01:04:38.996000    VER            1 0 days 00:01:21.032000
# 4 0 days 01:05:59.960000    VER            1 0 days 00:01:20.964000
#
#    LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# 0        1.0    1.0        NaT       NaT                    NaT
# 1        2.0    1.0        NaT       NaT 0 days 00:00:24.125000
# 2        3.0    1.0        NaT       NaT 0 days 00:00:23.816000
# 3        4.0    1.0        NaT       NaT 0 days 00:00:24.299000
# 4        5.0    1.0        NaT       NaT 0 days 00:00:24.223000
#
#              Sector2Time  ... FreshTyre             Team  \
# 0 0 days 00:00:32.318000  ...     False  Red Bull Racing
# ...

# %%
# Get Tyre Data
ver_tyre_data = slipsel.pick_tyre_data(ver)
ver_tyre_data.head(5)
# Out:
#   Driver  LapNumber Compound  TyreLife  FreshTyre  Stint
# 0    VER        1.0     SOFT       4.0      False    1.0
# 1    VER        2.0     SOFT       5.0      False    1.0
# 2    VER        3.0     SOFT       6.0      False    1.0
# 3    VER        4.0     SOFT       7.0      False    1.0
# 4    VER        5.0     SOFT       8.0      False    1.0

# %%
ver_tyre_data.groupby("Stint").agg({
    "LapNumber": ["min", "max"],
    "Compound": "first",
    "FreshTyre": "first"
})
# Out:
#       LapNumber       Compound FreshTyre
#             min   max    first     first
# Stint
# 1.0         1.0  13.0     SOFT     False
# 2.0        14.0  29.0     SOFT      True
# 3.0        30.0  47.0   MEDIUM      True
# 4.0        48.0  55.0     SOFT     False
# 5.0        56.0  66.0     HARD      True

# %%
#test
sample = lap_data[lap_data["Driver"] == "VER"]["Stint"].max()
sample
# Out:
# np.float64(5.0)

# %%
# Get the Stint of all drivers
grid_stint = grid.get_stint(lap_data)
grid_stint
# Out:
#    Driver  Total Stint  Pit Stops
# 0     ANT            3          2
# 1     ALB            3          2
# 2     OCO            3          2
# 3     LAW            3          2
# 4     BOR            3          2
# 5     HUL            4          3
# 6     ALO            4          3
# 7     GAS            4          3
# 8     COL            4          3
# 9     HAM            4          3
# 10    LEC            4          3
# 11    NOR            4          3
# 12    SAI            4          3
# 13    HAD            4          3
# 14    PIA            4          3
# 15    RUS            4          3
# 16    BEA            4          3
# 17    TSU            5          4
# 18    VER            5          4

# %%
lap_data[lap_data["Driver"] == "VER"]["Position"].isnull().any()
# Out:
# np.False_

# %%
# Get the Position Gain of Drivers
pos = grid.calc_position_gain(lap_data)
pos
# Out:
#    Driver  Position Gain
# 0     TSU              5
# 1     HUL              5
# 2     LAW              2
# 3     RUS              2
# 4     BEA              2
# 5     SAI              2
# 6     LEC              2
# 7     COL              2
# 8     HAD              1
# 9     NOR              1
# 10    ANT              0
# 11    PIA              0
# 12    BOR              0
# 13    ALO              0
# 14    GAS             -1
# 15    OCO             -1
# 16    VER             -3
# 17    HAM             -3
# 18    ALB             -5

# %%
# Measure tyre degradation!
import matplotlib.pyplot as plt
ver_clean = ver.pick_quicklaps()

plt.scatter(ver_clean["TyreLife"],ver_clean["LapTime"].dt.total_seconds())
plt.xlabel("TyreLife")
plt.ylabel("LapTime")
plt.show()
