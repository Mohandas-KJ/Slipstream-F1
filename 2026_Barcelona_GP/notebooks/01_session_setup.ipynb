# %% [markdown]
# # **Barcelona GP 2026**

# %%
#Imports
import fastf1
import pandas as pd
print("Imported!")
# Out:
# Imported!

# %%
#Caching
fastf1.Cache.enable_cache("../../cache")
print("Caching Enabled!")
# Out:
# Caching Enabled!

# %%
#Define Session
session = fastf1.get_session(
    2025,
    "Spanish Grand Prix",
    "Q"
)
print("Session Defined")
# Out:
# Session Defined

# %%
#Load Session
session.load()
print("Session Loaded")
# Out:
# core           INFO 	Loading data for Spanish Grand Prix - Qualifying [v3.8.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# ...

# %%
#Grand Prix Overview
session
# Out:
# 2025 Season Round 9: Spanish Grand Prix - Qualifying

# %%
#Results of Spain GP 2025
session.results
# Out:
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 81           81     O PIASTRI          PIA         piastri          McLaren
# 4             4      L NORRIS          NOR          norris          McLaren
# 1             1  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 63           63     G RUSSELL          RUS         russell         Mercedes
# 44           44    L HAMILTON          HAM        hamilton          Ferrari
# 12           12   K ANTONELLI          ANT       antonelli         Mercedes
# 16           16     C LECLERC          LEC         leclerc          Ferrari
# 10           10       P GASLY          GAS           gasly           Alpine
# 6             6      I HADJAR          HAD          hadjar     Racing Bulls
# 14           14      F ALONSO          ALO          alonso     Aston Martin
# 23           23       A ALBON          ALB           albon         Williams
# ...

# %%
#GP Quali Results with Filters
session.results[["Abbreviation","TeamName","Position"]]
# Out:
#    Abbreviation         TeamName  Position
# 81          PIA          McLaren       1.0
# 4           NOR          McLaren       2.0
# 1           VER  Red Bull Racing       3.0
# 63          RUS         Mercedes       4.0
# 44          HAM          Ferrari       5.0
# 12          ANT         Mercedes       6.0
# 16          LEC          Ferrari       7.0
# 10          GAS           Alpine       8.0
# 6           HAD     Racing Bulls       9.0
# 14          ALO     Aston Martin      10.0
# 23          ALB         Williams      11.0
# 5           BOR      Kick Sauber      12.0
# 30          LAW     Racing Bulls      13.0
# 18          STR     Aston Martin      14.0
# 87          BEA     Haas F1 Team      15.0
# 27          HUL      Kick Sauber      16.0
# 31          OCO     Haas F1 Team      17.0
# 55          SAI         Williams      18.0
# 43          COL           Alpine      19.0
# 22          TSU  Red Bull Racing      20.0

# %% [markdown]
# ## Race Analysis

# %%
import sys

sys.path.append("../..")

import Sliplib.slipload as sl

# %%
#Load Race session
race = sl.load_gp(2025,"Spanish Grand Prix","Race")

# %%
race.load()
# Out:
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.8.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# ...

# %%
race.results
# Out:
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 81           81     O PIASTRI          PIA         piastri          McLaren
# 4             4      L NORRIS          NOR          norris          McLaren
# 16           16     C LECLERC          LEC         leclerc          Ferrari
# 63           63     G RUSSELL          RUS         russell         Mercedes
# 27           27  N HULKENBERG          HUL      hulkenberg      Kick Sauber
# 44           44    L HAMILTON          HAM        hamilton          Ferrari
# 6             6      I HADJAR          HAD          hadjar     Racing Bulls
# 10           10       P GASLY          GAS           gasly           Alpine
# 14           14      F ALONSO          ALO          alonso     Aston Martin
# 1             1  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 30           30      L LAWSON          LAW          lawson     Racing Bulls
# ...

# %%
#Fetch results
race.results[["Abbreviation","TeamName","ClassifiedPosition"]]
# Out:
#    Abbreviation         TeamName ClassifiedPosition
# 81          PIA          McLaren                  1
# 4           NOR          McLaren                  2
# 16          LEC          Ferrari                  3
# 63          RUS         Mercedes                  4
# 27          HUL      Kick Sauber                  5
# 44          HAM          Ferrari                  6
# 6           HAD     Racing Bulls                  7
# 10          GAS           Alpine                  8
# 14          ALO     Aston Martin                  9
# 1           VER  Red Bull Racing                 10
# 30          LAW     Racing Bulls                 11
# 5           BOR      Kick Sauber                 12
# 22          TSU  Red Bull Racing                 13
# 55          SAI         Williams                 14
# 43          COL           Alpine                 15
# 31          OCO     Haas F1 Team                 16
# 87          BEA     Haas F1 Team                 17
# ...

# %%
race.results[["Abbreviation","Position","Status"]]
# Out:
#    Abbreviation  Position    Status
# 81          PIA       1.0  Finished
# 4           NOR       2.0  Finished
# 16          LEC       3.0  Finished
# 63          RUS       4.0  Finished
# 27          HUL       5.0  Finished
# 44          HAM       6.0  Finished
# 6           HAD       7.0  Finished
# 10          GAS       8.0  Finished
# 14          ALO       9.0  Finished
# 1           VER      10.0  Finished
# 30          LAW      11.0  Finished
# 5           BOR      12.0  Finished
# 22          TSU      13.0  Finished
# 55          SAI      14.0  Finished
# 43          COL      15.0  Finished
# 31          OCO      16.0  Finished
# 87          BEA      17.0  Finished
# 12          ANT      18.0   Retired
# 23          ALB      19.0   Retired
